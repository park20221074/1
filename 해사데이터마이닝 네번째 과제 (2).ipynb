# %% [markdown]
# <a href="https://colab.research.google.com/github/park20221074/1/blob/main/%ED%95%B4%EC%82%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A7%88%EC%9D%B4%EB%8B%9D%20%EB%84%A4%EB%B2%88%EC%A7%B8%20%EA%B3%BC%EC%A0%9C%20(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
weather_file = path + 'weather.csv'
weather = pd.read_csv(weather_file, encoding='CP949')

# '일시'에서 월 추출
weather['month'] = pd.DatetimeIndex(weather['일시']).month
monthly_wind = weather.groupby('month')['평균풍속'].mean()

# 그래프 그리기
months = np.arange(1, 13)
plt.bar(months, monthly_wind, color='green')
plt.xlabel('month')
plt.ylabel('wind')
plt.xticks(months)
plt.title('monthly wind')
plt.show()
